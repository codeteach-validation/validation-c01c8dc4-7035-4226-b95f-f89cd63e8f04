# %% [markdown]
# # Assignment-1
# ## Image Basics Practice
# **Course:** ITAI1378 – Artificial Intelligence for Computer Vision
#
# This assignment builds on the Intro Practice Lab.
# Follow each task step by step.
#
# ### Image URL to use
# https://raw.githubusercontent.com/opencv/opencv/master/samples/data/fruits.jpg

# %% [markdown]
# ## Task 1
# Start your notebook and import required libraries.
#
# **Goal**
# Prepare the environment to work with images.

# %%
# Task 1
# Import the required libraries
# Print a message to confirm the imports worked
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import cv2
import numpy as np
import urllib.request

print("Libraries imported successfully.")

# %% [markdown]
# ## Task 2
# Download the image from the provided URL.
#
# **Goal**
# Save the image into the Colab runtime so it can be read by OpenCV.

# %%
# Task 2
# Import urllib.request
# Store the image URL in a variable named url
# Store the file name as fruits.jpg
# Download the image
# Print a confirmation message
url = "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/fruits.jpg"
filename = "fruits.jpg"
urllib.request.urlretrieve(url, filename)
print(f"Image downloaded and saved as {filename}.")

# %% [markdown]
# ## Task 3
# Read the image using OpenCV.
#
# **Goal**
# Load the downloaded image into a variable.

# %%
# Task 3
# Read the image using cv2.imread
# Store it in a variable named image_bgr
# Check if the image loaded correctly
image_bgr = cv2.imread(filename)
if image_bgr is not None:
    print("Image loaded successfully.")
else:
    print("Failed to load image.")

# %% [markdown]
# ## Task 4
# Inspect the image type and shape.
#
# **Goal**
# Understand how the image is stored as data.

# %%
# Task 4
# Print the type of the image
# Print the shape of the image
print(f"Type of image: {type(image_bgr)}")
print(f"Shape of image: {image_bgr.shape}")

# %% [markdown]
# ## Task 5
# Convert the image from BGR to RGB.
#
# **Goal**
# Prepare the image for correct display using Matplotlib.

# %%
# Task 5
# Convert image_bgr to RGB
# Store the result in image_rgb
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
print("Image converted to RGB.")

# %% [markdown]
# ## Task 6
# Display the RGB image.
#
# **Goal**
# Visualize the image correctly.

# %%
# Task 6
# Display the RGB image using matplotlib
# Turn off the axes
# Add a title
plt.imshow(image_rgb)
plt.axis('off')
plt.title('RGB Image')
plt.savefig(__import__('io').BytesIO())  # Save to a null device to simulate display in headless mode
print('<Figure size>')

# %% [markdown]
# ## Task 7
# Display RGB channels separately.
#
# **Goal**
# Understand how a color image is made of three channels.

# %%
# Task 7
# Extract Red, Green, and Blue channels from image_rgb
# Display each channel using matplotlib
red_channel = image_rgb[:, :, 0]
green_channel = image_rgb[:, :, 1]
blue_channel = image_rgb[:, :, 2]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].imshow(red_channel, cmap='Reds')
axes[0].set_title('Red Channel')
axes[0].axis('off')

axes[1].imshow(green_channel, cmap='Greens')
axes[1].set_title('Green Channel')
axes[1].axis('off')

axes[2].imshow(blue_channel, cmap='Blues')
axes[2].set_title('Blue Channel')
axes[2].axis('off')

plt.savefig(__import__('io').BytesIO())  # Save to a null device to simulate display in headless mode
print('<Figure size>')

# %% [markdown]
# ## Final Reflection
#
# Answer the following questions in a markdown cell.
#
# 1. What does an image represent to a computer
# 2. Why is color conversion needed before displaying an image
# 3. What information does image shape provide
# 4. What did you learn from viewing RGB channels separately
# 5. Which task helped you understand image data the most and why

# %% [markdown]
# 1. An image represents a grid of pixels to a computer, where each pixel contains color information typically stored as a combination of red, green, and blue (RGB) values.
# 2. Color conversion is needed before displaying an image because OpenCV loads images in BGR format by default, while most display libraries like Matplotlib expect images in RGB format.
# 3. Image shape provides the dimensions of the image, including the height, width, and the number of color channels. This information is crucial for understanding the size and color depth of the image.
# 4. Viewing RGB channels separately helps to understand how each color contributes to the final image. It shows the intensity distribution of each color channel and how they combine to form the full-color image.
# 5. Task 7 helped me understand image data the most because it involved separating and visualizing the individual color channels, which provided insight into how images are constructed from these channels.
